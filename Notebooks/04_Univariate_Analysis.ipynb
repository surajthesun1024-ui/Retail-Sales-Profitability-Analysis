# %%
from google.colab import drive
drive.mount('/content/drive')

project_path= "/content/drive/MyDrive/Retail_EDA_Project/"

import pandas as pd

df= pd.read_csv(project_path+"Data/Processed/cleaned_superstore.csv")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df.describe().T
# Out:
#                 count        mean         std       min      25%     50%  \
# Sales          9977.0  230.148902  623.721409     0.444  17.3000  54.816
# Quantity       9977.0    3.790719    2.226657     1.000   2.0000   3.000
# Discount       9977.0    0.156278    0.206455     0.000   0.0000   0.200
# Profit         9977.0   28.690130  234.457840 -6599.978   1.7262   8.671
# Profit Margin  9977.0   12.011354   46.663769  -275.000   7.5000  27.000
#
#                    75%        max
# Sales          209.970  22638.480
# Quantity         5.000     14.000
# Discount         0.200      0.800
# Profit          29.372   8399.976
# Profit Margin   36.250     50.000

# %%
df['Sales'].describe()
# Out:
# count     9977.000000
# mean       230.148902
# std        623.721409
# min          0.444000
# 25%         17.300000
# 50%         54.816000
# 75%        209.970000
# max      22638.480000
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Sales'])

plt.xlim(0,5000)
plt.title('Sales Distribution')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
sns.boxplot(df['Sales'])

plt.title('Sales Boxplot')
plt.show()

# %%
#Analysis of 'Profit'
df['Profit'].describe()
# Out:
# count    9977.00000
# mean       28.69013
# std       234.45784
# min     -6599.97800
# 25%         1.72620
# 50%         8.67100
# 75%        29.37200
# max      8399.97600
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Profit'])

plt.xlim(-2000,2000)
plt.ylim(0,500)
plt.title('Profit Distribution')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(6,4))
plt.boxplot(df['Profit'])

plt.title('Profit Boxplot')
plt.show()

# %%
#Discount Analysis
df['Discount'].describe()
# Out:
# count    9977.000000
# mean        0.156278
# std         0.206455
# min         0.000000
# 25%         0.000000
# 50%         0.200000
# 75%         0.200000
# max         0.800000
# Name: Discount, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Discount', data=df)

plt.title('Discount Distribution')
plt.show()

# %%
#Quantity Analysis
df['Quantity'].describe()
# Out:
# count    9977.000000
# mean        3.790719
# std         2.226657
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        14.000000
# Name: Quantity, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.countplot(x='Quantity', data=df)

plt.title('Quantity Distribution')
plt.show()

# %%
#Profit Margin Analysis
df['Profit Margin'].describe()
# Out:
# count    9977.000000
# mean       12.011354
# std        46.663769
# min      -275.000000
# 25%         7.500000
# 50%        27.000000
# 75%        36.250000
# max        50.000000
# Name: Profit Margin, dtype: float64

# %%
plt.figure(figsize=(6,4))
sns.histplot(df['Profit Margin'])

plt.title('Profit Margin Distribution')
plt.show()

# %% [markdown]
# ##Key Findings
#
# 1. Sales distribution is heavily right-skewed.
# 2. Profit contains significant negative outliers
# 3. Most orders involve low quantities
# 4. High discounts appear frequently
